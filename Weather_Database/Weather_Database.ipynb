# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build URL for Weather Map API Call with API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hualmay
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | matay
# Processing Record 10 of Set 1 | sala consilina
# Processing Record 11 of Set 1 | zyryanka
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | zolotinka
# City not found. Skipping...
# Processing Record 14 of Set 1 | jati
# Processing Record 15 of Set 1 | rio gallegos
# Processing Record 16 of Set 1 | changji
# Processing Record 17 of Set 1 | soubre
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | isugod
# Processing Record 26 of Set 1 | biak
# Processing Record 27 of Set 1 | camacupa
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | amapa
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | tobolsk
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | ukiah
# Processing Record 35 of Set 1 | vaasa
# Processing Record 36 of Set 1 | bardstown
# Processing Record 37 of Set 1 | hondo
# Processing Record 38 of Set 1 | vostok
# Processing Record 39 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | tura
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | flic en flac
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | kashary
# Processing Record 45 of Set 1 | beringovskiy
# Processing Record 46 of Set 1 | ribeira brava
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | rincon
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | grindavik
# Processing Record 1 of Set 2 | okhotsk
# Processing Record 2 of Set 2 | tabas
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | cabedelo
# Processing Record 6 of Set 2 | yar-sale
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | kavaratti
# Processing Record 11 of Set 2 | kolokani
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | edd
# Processing Record 16 of Set 2 | sukhaya buyvola
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | bahia blanca
# Processing Record 20 of Set 2 | champerico
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | xuddur
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | winnemucca
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 2 | severomuysk
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | vallenar
# Processing Record 33 of Set 2 | andenes
# Processing Record 34 of Set 2 | olafsvik
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | rikitea
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | hobyo
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | taoudenni
# Processing Record 41 of Set 2 | tateyama
# Processing Record 42 of Set 2 | salisbury
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | bairiki
# Processing Record 47 of Set 2 | zhanaozen
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | mananjary
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | dalhousie
# Processing Record 6 of Set 3 | fuyang
# Processing Record 7 of Set 3 | port augusta
# Processing Record 8 of Set 3 | panaba
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | solnechnyy
# Processing Record 11 of Set 3 | vrangel
# Processing Record 12 of Set 3 | ujjain
# Processing Record 13 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 3 | karratha
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | half moon bay
# Processing Record 17 of Set 3 | kalemie
# Processing Record 18 of Set 3 | banjar
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | terrak
# Processing Record 21 of Set 3 | atar
# Processing Record 22 of Set 3 | cartagena
# Processing Record 23 of Set 3 | castlemaine
# Processing Record 24 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | busselton
# Processing Record 30 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 3 | whitehorse
# Processing Record 32 of Set 3 | palafrugell
# Processing Record 33 of Set 3 | grand gaube
# Processing Record 34 of Set 3 | tezu
# Processing Record 35 of Set 3 | lidkoping
# Processing Record 36 of Set 3 | vanimo
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | nha trang
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | astana
# Processing Record 41 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | yakeshi
# Processing Record 44 of Set 3 | bardsir
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | esna
# Processing Record 47 of Set 3 | berezhany
# Processing Record 48 of Set 3 | wilmington
# Processing Record 49 of Set 3 | hays
# Processing Record 50 of Set 3 | pyay
# Processing Record 1 of Set 4 | sooke
# Processing Record 2 of Set 4 | nuuk
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | tolaga bay
# Processing Record 6 of Set 4 | makakilo city
# Processing Record 7 of Set 4 | bubaque
# Processing Record 8 of Set 4 | dunedin
# Processing Record 9 of Set 4 | zyryanovsk
# Processing Record 10 of Set 4 | hamilton
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | tilichiki
# Processing Record 13 of Set 4 | tim
# Processing Record 14 of Set 4 | port lincoln
# Processing Record 15 of Set 4 | ugoofaaru
# Processing Record 16 of Set 4 | fare
# Processing Record 17 of Set 4 | moranbah
# Processing Record 18 of Set 4 | wronki
# Processing Record 19 of Set 4 | anito
# Processing Record 20 of Set 4 | maceio
# Processing Record 21 of Set 4 | axim
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | atkarsk
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | varkaus
# Processing Record 27 of Set 4 | shadegan
# Processing Record 28 of Set 4 | presidencia roque saenz pena
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 4 | eldoret
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | wawa
# Processing Record 34 of Set 4 | altayskoye
# Processing Record 35 of Set 4 | rosario do sul
# Processing Record 36 of Set 4 | titay
# Processing Record 37 of Set 4 | broome
# Processing Record 38 of Set 4 | necochea
# Processing Record 39 of Set 4 | nago
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | smithers
# Processing Record 42 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | ntoum
# Processing Record 45 of Set 4 | klyuchi
# Processing Record 46 of Set 4 | atuona
# Processing Record 47 of Set 4 | rawson
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | mehamn
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | skjervoy
# Processing Record 2 of Set 5 | srandakan
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | chapleau
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | machico
# Processing Record 8 of Set 5 | golakganj
# Processing Record 9 of Set 5 | oshikango
# Processing Record 10 of Set 5 | seoul
# Processing Record 11 of Set 5 | waingapu
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | kashi
# Processing Record 14 of Set 5 | hithadhoo
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-malo
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | kargopol
# Processing Record 21 of Set 5 | traverse city
# Processing Record 22 of Set 5 | alihe
# Processing Record 23 of Set 5 | fort frances
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | valparaiso
# Processing Record 26 of Set 5 | adre
# Processing Record 27 of Set 5 | bluff
# Processing Record 28 of Set 5 | nouadhibou
# Processing Record 29 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 5 | carupano
# Processing Record 31 of Set 5 | halifax
# Processing Record 32 of Set 5 | san patricio
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | tsabong
# Processing Record 35 of Set 5 | sept-iles
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | dongsheng
# Processing Record 38 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 5 | gaoua
# Processing Record 40 of Set 5 | ilulissat
# Processing Record 41 of Set 5 | punta de piedra
# Processing Record 42 of Set 5 | tabou
# Processing Record 43 of Set 5 | poum
# Processing Record 44 of Set 5 | angoche
# Processing Record 45 of Set 5 | chicama
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | aktash
# Processing Record 48 of Set 5 | uromi
# Processing Record 49 of Set 5 | vao
# Processing Record 50 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 6 | vega de alatorre
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | sola
# Processing Record 4 of Set 6 | sangar
# Processing Record 5 of Set 6 | kanniyakumari
# Processing Record 6 of Set 6 | kaseda
# Processing Record 7 of Set 6 | mecca
# Processing Record 8 of Set 6 | sao joao da barra
# Processing Record 9 of Set 6 | gondanglegi
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | byron bay
# Processing Record 12 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 6 | sao filipe
# Processing Record 14 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 6 | havelock
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | vardo
# Processing Record 18 of Set 6 | palana
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | arlit
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | puerto carreno
# Processing Record 23 of Set 6 | buckie
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | tongchuan
# Processing Record 26 of Set 6 | samarai
# Processing Record 27 of Set 6 | lichuan
# Processing Record 28 of Set 6 | bridlington
# Processing Record 29 of Set 6 | cap-aux-meules
# Processing Record 30 of Set 6 | atascadero
# Processing Record 31 of Set 6 | prince george
# Processing Record 32 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | dikson
# Processing Record 35 of Set 6 | zhanakorgan
# Processing Record 36 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 6 | romans-sur-isere
# Processing Record 38 of Set 6 | amalapuram
# Processing Record 39 of Set 6 | camocim
# Processing Record 40 of Set 6 | pacifica
# Processing Record 41 of Set 6 | pisco
# Processing Record 42 of Set 6 | jodhpur
# Processing Record 43 of Set 6 | nizhneangarsk
# Processing Record 44 of Set 6 | vestmannaeyjar
# Processing Record 45 of Set 6 | oum hadjer
# Processing Record 46 of Set 6 | kruisfontein
# Processing Record 47 of Set 6 | keti bandar
# Processing Record 48 of Set 6 | gaffney
# Processing Record 49 of Set 6 | mar del plata
# Processing Record 50 of Set 6 | clyde river
# Processing Record 1 of Set 7 | roma
# Processing Record 2 of Set 7 | flinders
# Processing Record 3 of Set 7 | mwene-ditu
# Processing Record 4 of Set 7 | upernavik
# Processing Record 5 of Set 7 | kerema
# Processing Record 6 of Set 7 | yulara
# Processing Record 7 of Set 7 | quatre cocos
# Processing Record 8 of Set 7 | urkut
# Processing Record 9 of Set 7 | imbituba
# Processing Record 10 of Set 7 | torbay
# Processing Record 11 of Set 7 | igarka
# Processing Record 12 of Set 7 | manaus
# Processing Record 13 of Set 7 | port elizabeth
# Processing Record 14 of Set 7 | tazmalt
# Processing Record 15 of Set 7 | nohar
# Processing Record 16 of Set 7 | tulua
# Processing Record 17 of Set 7 | sakakah
# Processing Record 18 of Set 7 | warrington
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | bonoua
# Processing Record 21 of Set 7 | talaya
# Processing Record 22 of Set 7 | sibolga
# Processing Record 23 of Set 7 | glendale
# Processing Record 24 of Set 7 | derzhavinsk
# Processing Record 25 of Set 7 | baruun-urt
# Processing Record 26 of Set 7 | auki
# Processing Record 27 of Set 7 | alta
# Processing Record 28 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 7 | fiche
# Processing Record 30 of Set 7 | mwingi
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | ponta delgada
# Processing Record 33 of Set 7 | leh
# Processing Record 34 of Set 7 | amqui
# Processing Record 35 of Set 7 | lagoa
# Processing Record 36 of Set 7 | felipe carrillo puerto
# Processing Record 37 of Set 7 | hereford
# Processing Record 38 of Set 7 | miri
# Processing Record 39 of Set 7 | tomatlan
# Processing Record 40 of Set 7 | mosetse
# Processing Record 41 of Set 7 | norrtalje
# Processing Record 42 of Set 7 | svetlyy
# Processing Record 43 of Set 7 | bugembe
# Processing Record 44 of Set 7 | goianira
# Processing Record 45 of Set 7 | honiara
# Processing Record 46 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | saint-augustin
# Processing Record 49 of Set 7 | rocha
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | faanui
# Processing Record 2 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 8 | oranjemund
# Processing Record 4 of Set 8 | tarko-sale
# Processing Record 5 of Set 8 | imuris
# Processing Record 6 of Set 8 | rorvik
# Processing Record 7 of Set 8 | preobrazheniye
# Processing Record 8 of Set 8 | kailua
# Processing Record 9 of Set 8 | ishigaki
# Processing Record 10 of Set 8 | hrubieszow
# Processing Record 11 of Set 8 | maues
# Processing Record 12 of Set 8 | shingu
# Processing Record 13 of Set 8 | faridkot
# Processing Record 14 of Set 8 | puri
# Processing Record 15 of Set 8 | storforshei
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | qandala
# Processing Record 18 of Set 8 | grand-lahou
# Processing Record 19 of Set 8 | huarmey
# Processing Record 20 of Set 8 | jalu
# Processing Record 21 of Set 8 | aromashevo
# Processing Record 22 of Set 8 | turuvekere
# Processing Record 23 of Set 8 | birjand
# Processing Record 24 of Set 8 | north bend
# Processing Record 25 of Set 8 | russell
# Processing Record 26 of Set 8 | skogn
# Processing Record 27 of Set 8 | oussouye
# Processing Record 28 of Set 8 | shulan
# Processing Record 29 of Set 8 | shenjiamen
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | sinop
# Processing Record 32 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 8 | takoradi
# Processing Record 34 of Set 8 | avera
# Processing Record 35 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 8 | klaksvik
# Processing Record 37 of Set 8 | uruacu
# Processing Record 38 of Set 8 | stykkisholmur
# Processing Record 39 of Set 8 | aksarka
# Processing Record 40 of Set 8 | terrace
# Processing Record 41 of Set 8 | katobu
# Processing Record 42 of Set 8 | omsukchan
# Processing Record 43 of Set 8 | bantou
# Processing Record 44 of Set 8 | limbang
# Processing Record 45 of Set 8 | coihaique
# Processing Record 46 of Set 8 | bilibino
# Processing Record 47 of Set 8 | koungou
# Processing Record 48 of Set 8 | mizpe ramon
# City not found. Skipping...
# Processing Record 49 of Set 8 | sechura
# Processing Record 50 of Set 8 | esperance
# Processing Record 1 of Set 9 | dakar
# Processing Record 2 of Set 9 | aswan
# Processing Record 3 of Set 9 | teya
# Processing Record 4 of Set 9 | katherine
# Processing Record 5 of Set 9 | meulaboh
# Processing Record 6 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 9 | rio cuarto
# Processing Record 8 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 9 | whitecourt
# Processing Record 10 of Set 9 | mumbwa
# Processing Record 11 of Set 9 | bonfim
# Processing Record 12 of Set 9 | pestravka
# Processing Record 13 of Set 9 | waitati
# Processing Record 14 of Set 9 | juneau
# Processing Record 15 of Set 9 | okha
# Processing Record 16 of Set 9 | lydenburg
# Processing Record 17 of Set 9 | trapani
# Processing Record 18 of Set 9 | bonavista
# Processing Record 19 of Set 9 | bismarck
# Processing Record 20 of Set 9 | san policarpo
# Processing Record 21 of Set 9 | kochinda
# Processing Record 22 of Set 9 | saint-francois
# Processing Record 23 of Set 9 | rabo de peixe
# Processing Record 24 of Set 9 | wetaskiwin
# Processing Record 25 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 26 of Set 9 | trat
# Processing Record 27 of Set 9 | walvis bay
# Processing Record 28 of Set 9 | taksimo
# Processing Record 29 of Set 9 | hegang
# Processing Record 30 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 9 | fort wellington
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | cabiraoan
# Processing Record 34 of Set 9 | manadhoo
# Processing Record 35 of Set 9 | cockburn town
# Processing Record 36 of Set 9 | russkaya polyana
# Processing Record 37 of Set 9 | sao gabriel da cachoeira
# Processing Record 38 of Set 9 | quelimane
# Processing Record 39 of Set 9 | boyolangu
# Processing Record 40 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 9 | charyshskoye
# Processing Record 42 of Set 9 | north platte
# Processing Record 43 of Set 9 | khandyga
# Processing Record 44 of Set 9 | konotop
# Processing Record 45 of Set 9 | kandava
# Processing Record 46 of Set 9 | nakambala
# Processing Record 47 of Set 9 | moroni
# Processing Record 48 of Set 9 | manyana
# Processing Record 49 of Set 9 | sinnamary
# Processing Record 50 of Set 9 | ravar
# Processing Record 1 of Set 10 | aksha
# Processing Record 2 of Set 10 | sabang
# Processing Record 3 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 10 | korla
# Processing Record 5 of Set 10 | cam ranh
# Processing Record 6 of Set 10 | sitka
# Processing Record 7 of Set 10 | mgandu
# Processing Record 8 of Set 10 | kirovskiy
# Processing Record 9 of Set 10 | norman wells
# Processing Record 10 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 10 | mirnyy
# Processing Record 12 of Set 10 | marsh harbour
# Processing Record 13 of Set 10 | port shepstone
# Processing Record 14 of Set 10 | saint anthony
# Processing Record 15 of Set 10 | yuncheng
# Processing Record 16 of Set 10 | sobolevo
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | asau
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | mathbaria
# Processing Record 21 of Set 10 | vanderhoof
# Processing Record 22 of Set 10 | kattivakkam
# Processing Record 23 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 10 | saint-die
# City not found. Skipping...
# Processing Record 25 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | saskylakh
# Processing Record 27 of Set 10 | matara
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | broken hill
# Processing Record 30 of Set 10 | toccoa
# Processing Record 31 of Set 10 | padang
# Processing Record 32 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 10 | shetpe
# Processing Record 35 of Set 10 | tommot
# Processing Record 36 of Set 10 | tazovskiy
# Processing Record 37 of Set 10 | iberia
# Processing Record 38 of Set 10 | tigil
# Processing Record 39 of Set 10 | abancay
# Processing Record 40 of Set 10 | srednekolymsk
# Processing Record 41 of Set 10 | cabatuan
# Processing Record 42 of Set 10 | kyabram
# Processing Record 43 of Set 10 | kharan
# Processing Record 44 of Set 10 | marzuq
# Processing Record 45 of Set 10 | darhan
# Processing Record 46 of Set 10 | kirakira
# Processing Record 47 of Set 10 | natchez
# Processing Record 48 of Set 10 | falesti
# Processing Record 49 of Set 10 | chamba
# Processing Record 50 of Set 10 | maxixe
# Processing Record 1 of Set 11 | buchanan
# Processing Record 2 of Set 11 | zheshart
# Processing Record 3 of Set 11 | eureka
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | ixtapa
# Processing Record 6 of Set 11 | baghdad
# Processing Record 7 of Set 11 | agua verde
# Processing Record 8 of Set 11 | salta
# Processing Record 9 of Set 11 | ewo
# Processing Record 10 of Set 11 | virginia beach
# Processing Record 11 of Set 11 | liverpool
# Processing Record 12 of Set 11 | cabo san lucas
# Processing Record 13 of Set 11 | kieta
# Processing Record 14 of Set 11 | aksu
# Processing Record 15 of Set 11 | noumea
# Processing Record 16 of Set 11 | dinguiraye
# Processing Record 17 of Set 11 | kangaatsiaq
# Processing Record 18 of Set 11 | rawah
# Processing Record 19 of Set 11 | mapastepec
# Processing Record 20 of Set 11 | lamphun
# Processing Record 21 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 22 of Set 11 | dzaoudzi
# Processing Record 23 of Set 11 | ambon
# Processing Record 24 of Set 11 | yarada
# Processing Record 25 of Set 11 | verkhnyaya inta
# Processing Record 26 of Set 11 | sungurlu
# Processing Record 27 of Set 11 | severnyy
# Processing Record 28 of Set 11 | kudat
# Processing Record 29 of Set 11 | buala
# Processing Record 30 of Set 11 | bilma
# Processing Record 31 of Set 11 | totma
# Processing Record 32 of Set 11 | gat
# Processing Record 33 of Set 11 | kaliua
# Processing Record 34 of Set 11 | kahului
# Processing Record 35 of Set 11 | abu samrah
# Processing Record 36 of Set 11 | vestmanna
# Processing Record 37 of Set 11 | kawalu
# Processing Record 38 of Set 11 | buin
# Processing Record 39 of Set 11 | halle
# Processing Record 40 of Set 11 | laguna
# Processing Record 41 of Set 11 | groningen
# Processing Record 42 of Set 11 | harper
# Processing Record 43 of Set 11 | kologriv
# Processing Record 44 of Set 11 | westerland
# Processing Record 45 of Set 11 | pychas
# Processing Record 46 of Set 11 | la ronge
# Processing Record 47 of Set 11 | lashio
# Processing Record 48 of Set 11 | vieques
# Processing Record 49 of Set 11 | stornoway
# Processing Record 50 of Set 11 | pocoes
# Processing Record 1 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 12 | hambantota
# Processing Record 3 of Set 12 | wajir
# Processing Record 4 of Set 12 | mathathane
# Processing Record 5 of Set 12 | dudinka
# Processing Record 6 of Set 12 | moses lake
# Processing Record 7 of Set 12 | langtad
# Processing Record 8 of Set 12 | novyy urengoy
# Processing Record 9 of Set 12 | adrar
# Processing Record 10 of Set 12 | shenzhen
# Processing Record 11 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 12 | surgut
# Processing Record 13 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 12 | bastia
# Processing Record 15 of Set 12 | carndonagh
# Processing Record 16 of Set 12 | coxim
# Processing Record 17 of Set 12 | sar-e pul
# Processing Record 18 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 12 | cravo norte
# Processing Record 20 of Set 12 | mahanoro
# Processing Record 21 of Set 12 | gilbues
# Processing Record 22 of Set 12 | xai-xai
# Processing Record 23 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 24 of Set 12 | coahuayana
# Processing Record 25 of Set 12 | pauini
# Processing Record 26 of Set 12 | jalingo
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | bara
# Processing Record 29 of Set 12 | malindi
# Processing Record 30 of Set 12 | awjilah
# Processing Record 31 of Set 12 | kudahuvadhoo
# Processing Record 32 of Set 12 | sorland
# Processing Record 33 of Set 12 | senneterre
# Processing Record 34 of Set 12 | chernyshevskiy
# Processing Record 35 of Set 12 | ngaoundere
# Processing Record 36 of Set 12 | soure
# Processing Record 37 of Set 12 | boguchany
# Processing Record 38 of Set 12 | sutton
# Processing Record 39 of Set 12 | beidao
# Processing Record 40 of Set 12 | aras
# Processing Record 41 of Set 12 | honningsvag
# Processing Record 42 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 12 | san lawrenz
# Processing Record 44 of Set 12 | te anau
# Processing Record 45 of Set 12 | oktyabrskoye
# Processing Record 46 of Set 12 | ipixuna
# Processing Record 47 of Set 12 | superior
# Processing Record 48 of Set 12 | erdaojiang
# Processing Record 49 of Set 12 | salina cruz
# Processing Record 50 of Set 12 | chibombo
# Processing Record 1 of Set 13 | khuzhir
# Processing Record 2 of Set 13 | abapo
# Processing Record 3 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 13 | reconquista
# Processing Record 5 of Set 13 | ziro
# Processing Record 6 of Set 13 | hofn
# Processing Record 7 of Set 13 | coffs harbour
# Processing Record 8 of Set 13 | merauke
# Processing Record 9 of Set 13 | bayan
# Processing Record 10 of Set 13 | westport
# Processing Record 11 of Set 13 | saint-pierre
# Processing Record 12 of Set 13 | ranfurly
# Processing Record 13 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 13 | kasongo
# Processing Record 15 of Set 13 | atherton
# Processing Record 16 of Set 13 | chihuahua
# Processing Record 17 of Set 13 | saint-denis
# Processing Record 18 of Set 13 | changli
# Processing Record 19 of Set 13 | nizwa
# Processing Record 20 of Set 13 | lata
# Processing Record 21 of Set 13 | dali
# Processing Record 22 of Set 13 | puerto maldonado
# Processing Record 23 of Set 13 | teknaf
# Processing Record 24 of Set 13 | lerwick
# Processing Record 25 of Set 13 | leninskoye
# Processing Record 26 of Set 13 | riverton
# Processing Record 27 of Set 13 | washington
# Processing Record 28 of Set 13 | port hardy
# Processing Record 29 of Set 13 | cerrito
# Processing Record 30 of Set 13 | vila velha
# Processing Record 31 of Set 13 | inhambane
# Processing Record 32 of Set 13 | ko samui
# Processing Record 33 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 13 | chumikan
# Processing Record 35 of Set 13 | komsomolskiy
# Processing Record 36 of Set 13 | udachnyy
# Processing Record 37 of Set 13 | caravelas
# Processing Record 38 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 13 | bereda
# Processing Record 40 of Set 13 | bulgan
# Processing Record 41 of Set 13 | vila franca do campo
# Processing Record 42 of Set 13 | san carlos de bariloche
# Processing Record 43 of Set 13 | kulhudhuffushi
# Processing Record 44 of Set 13 | micheweni
# Processing Record 45 of Set 13 | ye
# City not found. Skipping...
# Processing Record 46 of Set 13 | hervey bay
# Processing Record 47 of Set 13 | mayo
# Processing Record 48 of Set 13 | luwuk
# Processing Record 49 of Set 13 | lubango
# Processing Record 50 of Set 13 | hudson bay
# Processing Record 1 of Set 14 | fort morgan
# Processing Record 2 of Set 14 | weihe
# Processing Record 3 of Set 14 | khorinsk
# Processing Record 4 of Set 14 | cururupu
# Processing Record 5 of Set 14 | narrabri
# Processing Record 6 of Set 14 | kamina
# Processing Record 7 of Set 14 | ahuimanu
# Processing Record 8 of Set 14 | ola
# Processing Record 9 of Set 14 | constitucion
# Processing Record 10 of Set 14 | dubai
# Processing Record 11 of Set 14 | diffa
# Processing Record 12 of Set 14 | pangai
# Processing Record 13 of Set 14 | jardim
# Processing Record 14 of Set 14 | tortoli
# Processing Record 15 of Set 14 | verkhoyansk
# Processing Record 16 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 17 of Set 14 | neryungri
# Processing Record 18 of Set 14 | cayenne
# Processing Record 19 of Set 14 | iquitos
# Processing Record 20 of Set 14 | oriximina
# Processing Record 21 of Set 14 | nome
# Processing Record 22 of Set 14 | veshenskaya
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 14 | saint paul
# Processing Record 26 of Set 14 | santa cruz
# Processing Record 27 of Set 14 | puro
# Processing Record 28 of Set 14 | riyadh
# Processing Record 29 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 14 | itacare
# Processing Record 31 of Set 14 | qui nhon
# Processing Record 32 of Set 14 | calama
# Processing Record 33 of Set 14 | la palma
# Processing Record 34 of Set 14 | wanning
# Processing Record 35 of Set 14 | roald
# Processing Record 36 of Set 14 | aykhal
# Processing Record 37 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 14 | acarau
# Processing Record 39 of Set 14 | puerto colombia
# Processing Record 40 of Set 14 | libertador general san martin
# Processing Record 41 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 14 | sirur
# Processing Record 43 of Set 14 | tiznit
# Processing Record 44 of Set 14 | ushtobe
# Processing Record 45 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 46 of Set 14 | safita
# Processing Record 47 of Set 14 | shimoda
# Processing Record 48 of Set 14 | saint-georges
# Processing Record 49 of Set 14 | mayen
# Processing Record 50 of Set 14 | sisimiut
# Processing Record 1 of Set 15 | fairbanks
# Processing Record 2 of Set 15 | manyoni
# Processing Record 3 of Set 15 | bandarbeyla
# Processing Record 4 of Set 15 | namibe
# Processing Record 5 of Set 15 | badiraguato
# Processing Record 6 of Set 15 | majene
# Processing Record 7 of Set 15 | camacha
# Processing Record 8 of Set 15 | burnie
# Processing Record 9 of Set 15 | along
# Processing Record 10 of Set 15 | saquena
# Processing Record 11 of Set 15 | egvekinot
# Processing Record 12 of Set 15 | zhigalovo
# Processing Record 13 of Set 15 | fortuna
# Processing Record 14 of Set 15 | coquimbo
# Processing Record 15 of Set 15 | sampit
# Processing Record 16 of Set 15 | tonantins
# Processing Record 17 of Set 15 | jiaojiang
# Processing Record 18 of Set 15 | panalingaan
# Processing Record 19 of Set 15 | tucuma
# Processing Record 20 of Set 15 | tautira
# Processing Record 21 of Set 15 | chulman
# Processing Record 22 of Set 15 | camana
# Processing Record 23 of Set 15 | santa vitoria do palmar
# Processing Record 24 of Set 15 | hundested
# Processing Record 25 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 15 | kamenka
# Processing Record 27 of Set 15 | campo verde
# Processing Record 28 of Set 15 | pemangkat
# Processing Record 29 of Set 15 | oranjestad
# Processing Record 30 of Set 15 | saint-joseph
# Processing Record 31 of Set 15 | yenagoa
# Processing Record 32 of Set 15 | guilin
# Processing Record 33 of Set 15 | vuktyl
# Processing Record 34 of Set 15 | mount isa
# Processing Record 35 of Set 15 | callaway
# Processing Record 36 of Set 15 | wagar
# Processing Record 37 of Set 15 | namatanai
# Processing Record 38 of Set 15 | abu dhabi
# Processing Record 39 of Set 15 | hihya
# Processing Record 40 of Set 15 | nampula
# Processing Record 41 of Set 15 | lamu
# Processing Record 42 of Set 15 | khasan
# Processing Record 43 of Set 15 | eyl
# Processing Record 44 of Set 15 | wesselsbron
# Processing Record 45 of Set 15 | chiang rai
# Processing Record 46 of Set 15 | moctezuma
# Processing Record 47 of Set 15 | manokwari
# Processing Record 48 of Set 15 | lobito
# Processing Record 49 of Set 15 | scarborough
# Processing Record 50 of Set 15 | goderich
# Processing Record 1 of Set 16 | tiarei
# Processing Record 2 of Set 16 | tottori
# Processing Record 3 of Set 16 | alice springs
# Processing Record 4 of Set 16 | natal
# Processing Record 5 of Set 16 | nuevo progreso
# Processing Record 6 of Set 16 | atambua
# Processing Record 7 of Set 16 | kendari
# Processing Record 8 of Set 16 | maniitsoq
# Processing Record 9 of Set 16 | griffith
# Processing Record 10 of Set 16 | dingle
# Processing Record 11 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 16 | gold coast
# Processing Record 13 of Set 16 | agadir
# Processing Record 14 of Set 16 | okitipupa
# Processing Record 15 of Set 16 | aden
# Processing Record 16 of Set 16 | novska
# Processing Record 17 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 16 | chagoda
# Processing Record 19 of Set 16 | raudeberg
# Processing Record 20 of Set 16 | omboue
# Processing Record 21 of Set 16 | dalbandin
# Processing Record 22 of Set 16 | marfino
# Processing Record 23 of Set 16 | catabola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City  Cloudiness Country          Current Description  Humidity  \
# 0         Hualmay          99      PE              overcast clouds        82
# 1         Ushuaia          75      AR                   light rain        81
# 2         Kavieng         100      PG                moderate rain        80
# 3          Hasaki          95      JP              overcast clouds        80
# 4          Bethel          90      US              overcast clouds        77
# 5    Punta Arenas          75      CL  light intensity shower rain        87
# 6        Katsuura         100      JP              overcast clouds        83
# 7           Matay         100      EG              overcast clouds        61
# 8  Sala Consilina          91      IT              overcast clouds        93
# 9        Zyryanka          91      RU              overcast clouds        99
#
#        Lat       Lng  Max Temp  Wind Speed
# 0 -11.0964  -77.6139     67.64        8.41
# 1 -54.8000  -68.3000     47.86       14.97
# 2  -2.5744  150.7967     81.46       14.20
# 3  35.7333  140.8333     61.20       21.30
# 4  41.3712  -73.4140     52.38        8.01
# 5 -53.1500  -70.9167     50.11       23.02
# 6  35.1333  140.3000     63.19       20.00
# 7  28.4190   30.7792     59.88        5.35
# 8  40.3912   15.5989     40.39        5.57
# 9  65.7500  150.8500    -42.95        3.04

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hualmay      PE -11.0964  -77.6139     67.64        82          99
# 1         Ushuaia      AR -54.8000  -68.3000     47.86        81          75
# 2         Kavieng      PG  -2.5744  150.7967     81.46        80         100
# 3          Hasaki      JP  35.7333  140.8333     61.20        80          95
# 4          Bethel      US  41.3712  -73.4140     52.38        77          90
# 5    Punta Arenas      CL -53.1500  -70.9167     50.11        87          75
# 6        Katsuura      JP  35.1333  140.3000     63.19        83         100
# 7           Matay      EG  28.4190   30.7792     59.88        61         100
# 8  Sala Consilina      IT  40.3912   15.5989     40.39        93          91
# 9        Zyryanka      RU  65.7500  150.8500    -42.95        99          91
#
#    Wind Speed          Current Description
# 0        8.41              overcast clouds
# 1       14.97                   light rain
# 2       14.20                moderate rain
# 3       21.30              overcast clouds
# 4        8.01              overcast clouds
# 5       23.02  light intensity shower rain
# 6       20.00              overcast clouds
# 7        5.35              overcast clouds
# 8        5.57              overcast clouds
# 9        3.04              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
